# %% [markdown]
# <a href="https://colab.research.google.com/github/samuel65677/MagiskOnWSA-1/blob/main/Fat%20llama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cupy
# !pip install fat-llama
# Out:
# ERROR: Could not find a version that satisfies the requirement cupy-cuda112 (from versions: none)
# ERROR: No matching distribution found for cupy-cuda112
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 14.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  uploaded_filename = fn # Store the uploaded filename in a variable

from fat_llama.audio_fattener.feed import upscale

# Example call to the method
upscale(
    input_file_path='input_test.mp3',
    output_file_path='output_test.flac',
    source_format='mp3',
    target_format='flac',
    max_iterations=300,
    threshold_value=0.6,
    target_bitrate_kbps=1400,
    toggle_normalize=True,
    toggle_autoscale=True,
    toggle_adaptive_filter=True
)
